# %%
from knowledge_graph_adapter import KnowledgeGraphAdapter

# %%
adapter = KnowledgeGraphAdapter(
    'http://localhost:7200/repositories/REFORMERS'
)

# %%
info = adapter.retrieve_turbine_info(scenario_name='Baseline')

# %%
import pprint
pprint.pprint(info)
# Out:
# {'Turbine0': {'Hub Height': 85.0,
#               'Power Curve': [[1.0, 0.0],
#                               [2.0, 3000.0],
#                               [3.0, 25000.0],
#                               [4.0, 82000.0],
#                               [5.0, 174000.0],
#                               [6.0, 321000.0],
#                               [7.0, 532000.0],
#                               [8.0, 815000.0],
#                               [9.0, 1180000.0],
#                               [10.0, 1580000.0],
#                               [11.0, 1890000.0],
#                               [12.0, 2100000.0],
#                               [13.0, 2250000.0],
#                               [14.0, 2350000.0],
#                               [15.0, 2350000.0],
#                               [16.0, 2350000.0],
#                               [17.0, 2350000.0],
#                               [18.0, 2350000.0],
#                               [19.0, 2350000.0],
# ...
