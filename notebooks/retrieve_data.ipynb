# %%
from knowledge_graph_adapter import KnowledgeGraphAdapter
import pprint

# %%
adapter = KnowledgeGraphAdapter(
    'http://localhost:7200/repositories/REFORMERS'
)

# %%
windpark_info = adapter.retrieve_windpark_info(
    scenario='BaselineAlkmaar', global_wind_atlas_site='WindparkAlkmaar'
    )

# %%
pprint.pprint(windpark_info)
# Out:
# {'WindparkAlkmaar': {'Roughness': {'unit': 'http://qudt.org/vocab/unit/UNITLESS',
#                                    'value': 1.0}}}

# %%
turbine_info = adapter.retrieve_turbine_info(
    scenario='BaselineAlkmaar', global_wind_atlas_site='WindparkAlkmaar'
    )

# %%
pprint.pprint(turbine_info)
# Out:
# {'Alkmaar 1': {'Altitude': {'unit': 'http://qudt.org/vocab/unit/M',
#                             'value': 10.0},
#                'Hub Height': {'unit': 'http://qudt.org/vocab/unit/CentiM',
#                               'value': 8500.0},
#                'Latitude': {'unit': 'http://qudt.org/vocab/unit/DEG',
#                             'value': 52.592999},
#                'Longitude': {'unit': 'http://qudt.org/vocab/unit/DEG',
#                              'value': 4.752301},
#                'Rated Power': {'unit': 'http://qudt.org/vocab/unit/MegaW',
#                                'value': 2.3},
#                'Rotor Diameter': {'unit': 'http://qudt.org/vocab/unit/CentiM',
#                                   'value': 8200.0},
#                'Wind Turbine Type': {'value': 'Alkmaar_2p3MW'}},
#  'Alkmaar 2': {'Altitude': {'unit': 'http://qudt.org/vocab/unit/M',
#                             'value': 120.0},
# ...

# %%
turbine_types = adapter.retrieve_turbine_types(
    scenario='BaselineAlkmaar', global_wind_atlas_site='WindparkAlkmaar'
    )

# %%
pprint.pprint(turbine_types)
# Out:
# {'Alkmaar_2p3MW': {'Power Curve': {'unit': ['http://qudt.org/vocab/unit/M-PER-SEC',
#                                             'http://qudt.org/vocab/unit/W'],
#                                    'value': [[1.0, 0.0],
#                                              [2.0, 3000.0],
#                                              [3.0, 25000.0],
#                                              [4.0, 82000.0],
#                                              [5.0, 174000.0],
#                                              [6.0, 321000.0],
#                                              [7.0, 532000.0],
#                                              [8.0, 815000.0],
#                                              [9.0, 1180000.0],
#                                              [10.0, 1580000.0],
#                                              [11.0, 1890000.0],
#                                              [12.0, 2100000.0],
#                                              [13.0, 2250000.0],
# ...
